# %%
import pandas as pd

# %%
df = pd.read_csv('orange_inc.csv', index_col=0)
df
# Out:
#         age_bracket      tier  gender oPhone oWatch oPods oTV        date  \
# user_id
# 1             18-25    silver  female      0      0     1   0  2023-11-23
# 2             25-34      gold  female      1      1     0   0  2023-07-27
# 3             25-34      gold  female      1      0     0   0  2023-03-03
# 4             25-34    silver  female      1      0     1   0  2023-10-09
# 5             34-50      gold  female      0      0     1   0  2023-08-18
# ...             ...       ...     ...    ...    ...   ...  ..         ...
# 19996         18-25    silver  female      0      1     0   0  2023-05-26
# 19997         18-25    silver  female      0      0     1   0  2023-08-30
# 19998         18-25    silver  female      0      0     0   1  2023-12-21
# 19999         25-34  platinum  female      1      1     1   0  2023-04-06
# 20000         18-25    silver    male      1      1     0   0  2023-12-07
#
#                       card
# user_id
# 1               Visa_debit
# ...

# %%
(df['age_bracket'] == '-').sum()
# Out:
# np.int64(53)

# %%
(df['tier'] == '-').sum()
# Out:
# np.int64(28)

# %%
(df['gender'] == '-').sum()
# Out:
# np.int64(152)

# %%
(df['oPhone'] == '-').sum()
# Out:
# np.int64(50)

# %%
(df['oWatch'] == '-').sum()
# Out:
# np.int64(40)

# %%
(df['oPods'] == '-').sum()
# Out:
# np.int64(45)

# %%
(df['oTV'] == '-').sum()
# Out:
# np.int64(30)

# %%
(df['date'] == '-').sum()
# Out:
# np.int64(17)

# %%
(df['card'] == '-').sum()
# Out:
# np.int64(20)

# %%
orange_data_clean =  df[(df['age_bracket'] != '-') & (df['tier'] != '-') & (df['gender'] != '-') & (df['oPhone'] != '-') & (df['oWatch'] != '-') & (df['oPods'] != '-') & (df['oTV'] != '-') & (df['date'] != '-') & (df['card'] != '-')]
orange_data_clean
# Out:
#         age_bracket      tier  gender oPhone oWatch oPods oTV        date  \
# user_id
# 1             18-25    silver  female      0      0     1   0  2023-11-23
# 2             25-34      gold  female      1      1     0   0  2023-07-27
# 3             25-34      gold  female      1      0     0   0  2023-03-03
# 4             25-34    silver  female      1      0     1   0  2023-10-09
# 5             34-50      gold  female      0      0     1   0  2023-08-18
# ...             ...       ...     ...    ...    ...   ...  ..         ...
# 19996         18-25    silver  female      0      1     0   0  2023-05-26
# 19997         18-25    silver  female      0      0     1   0  2023-08-30
# 19998         18-25    silver  female      0      0     0   1  2023-12-21
# 19999         25-34  platinum  female      1      1     1   0  2023-04-06
# 20000         18-25    silver    male      1      1     0   0  2023-12-07
#
#                       card
# user_id
# 1               Visa_debit
# ...

# %%
len(orange_data_clean)
# Out:
# 19567

# %%
orange_data_clean['oPhone']= orange_data_clean['oPhone'].astype(int)
orange_data_clean['oWatch']= orange_data_clean['oWatch'].astype(int)
orange_data_clean['oPods']= orange_data_clean['oPods'].astype(int)
orange_data_clean['oTV']= orange_data_clean['oTV'].astype(int)
# Out:
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/4024748287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orange_data_clean['oPhone']= orange_data_clean['oPhone'].astype(int)
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/4024748287.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orange_data_clean['oWatch']= orange_data_clean['oWatch'].astype(int)
# ...

# %%
orange_data_clean.dtypes
# Out:
# age_bracket    object
# tier           object
# gender         object
# oPhone          int64
# oWatch          int64
# oPods           int64
# oTV             int64
# date           object
# card           object
# dtype: object

# %%
cols = ['oPhone', 'oWatch', 'oPods', 'oTV']
orange_data_clean['owns_multiple_products'] = orange_data_clean['oPhone'] + orange_data_clean['oWatch'] + orange_data_clean['oPods'] + orange_data_clean['oTV']
# Out:
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/1600536660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orange_data_clean['owns_multiple_products'] = orange_data_clean['oPhone'] + orange_data_clean['oWatch'] + orange_data_clean['oPods'] + orange_data_clean['oTV']

# %%
orange_data_clean['owns_multiple_products'] = orange_data_clean['owns_multiple_products'].apply(lambda x: 1 if x >= 2 else 0 )
orange_data_clean['owns_multiple_products'] = orange_data_clean['owns_multiple_products'].astype(int)
orange_data_clean.dtypes
# Out:
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/3093470890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orange_data_clean['owns_multiple_products'] = orange_data_clean['owns_multiple_products'].apply(lambda x: 1 if x >= 2 else 0 )
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/3093470890.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orange_data_clean['owns_multiple_products'] = orange_data_clean['owns_multiple_products'].astype(int)
# ...

# %%
orange_data_clean[orange_data_clean['owns_multiple_products'] >= 1]
# Out:
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 2             25-34      gold  female       1       1      0    0  2023-07-27
# 4             25-34    silver  female       1       0      1    0  2023-10-09
# 6             25-34    silver    male       1       1      0    0  2023-05-10
# 12            25-34    silver  female       0       1      1    0  2023-06-14
# 13            18-25    silver    male       1       0      1    0  2023-10-07
# ...             ...       ...     ...     ...     ...    ...  ...         ...
# 19990         18-25    silver  female       1       0      1    0  2023-03-18
# 19993         18-25    silver  female       0       1      1    0  2023-02-26
# 19995         25-34      gold  female       1       0      1    0  2023-11-28
# 19999         25-34  platinum  female       1       1      1    0  2023-04-06
# 20000         18-25    silver    male       1       1      0    0  2023-12-07
#
# ...

# %%
orange_data_clean['age_bracket'].value_counts()
# Out:
# age_bracket
# 18-25    8702
# 25-34    6950
# 34-50    2982
# >50       933
# Name: count, dtype: int64

# %%
orange_data_clean['card'].value_counts()
# Out:
# card
# Visa_debit           8415
# Mastercard_credit    4103
# Visa_credit          3400
# Mastercard_debit     2108
# Other_debit          1331
# Other_credit          210
# Name: count, dtype: int64

# %%
orange_data_clean['gender'].value_counts()
# Out:
# gender
# female    10966
# male       7820
# other       781
# Name: count, dtype: int64

# %%
orange_data_clean
# Out:
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 1             18-25    silver  female       0       0      1    0  2023-11-23
# 2             25-34      gold  female       1       1      0    0  2023-07-27
# 3             25-34      gold  female       1       0      0    0  2023-03-03
# 4             25-34    silver  female       1       0      1    0  2023-10-09
# 5             34-50      gold  female       0       0      1    0  2023-08-18
# ...             ...       ...     ...     ...     ...    ...  ...         ...
# 19996         18-25    silver  female       0       1      0    0  2023-05-26
# 19997         18-25    silver  female       0       0      1    0  2023-08-30
# 19998         18-25    silver  female       0       0      0    1  2023-12-21
# 19999         25-34  platinum  female       1       1      1    0  2023-04-06
# 20000         18-25    silver    male       1       1      0    0  2023-12-07
#
# ...

# %%
df_2 = orange_data_clean[(orange_data_clean['age_bracket'] == '18-25') & (orange_data_clean['gender'] == 'female') & (orange_data_clean['card'].isin(['Mastercard_credit','Visa_credit']))]
df_2
# Out:
#         age_bracket    tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 19            18-25  silver  female       1       0      0    0  2023-04-21
# 25            18-25    gold  female       1       1      0    0  2023-01-27
# 38            18-25  silver  female       0       0      1    0  2023-12-08
# 43            18-25    gold  female       1       0      0    0  2023-08-01
# 64            18-25    gold  female       0       0      1    0  2023-03-17
# ...             ...     ...     ...     ...     ...    ...  ...         ...
# 19945         18-25  silver  female       0       0      1    0  2023-12-21
# 19957         18-25    gold  female       0       0      0    1  2023-06-20
# 19961         18-25  silver  female       1       0      0    1  2023-03-28
# 19971         18-25  silver  female       1       1      0    0  2023-02-03
# 19990         18-25  silver  female       1       0      1    0  2023-03-18
#
# ...

# %%
filtered = orange_data_clean.loc[orange_data_clean['age_bracket'] != '18-25' ]
older_than_25 = filtered['age_bracket'].unique().tolist()
older_than_25
# Out:
# ['25-34', '34-50', '>50']

# %%
debit_list = ['Visa_debit', 'Mastercard_debit', 'Other_debit']
df2 = orange_data_clean[(orange_data_clean['age_bracket'].isin(older_than_25)) & (orange_data_clean['owns_multiple_products'] == 1) & (orange_data_clean['card'].isin(debit_list))] 
df2
# Out:
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 2             25-34      gold  female       1       1      0    0  2023-07-27
# 26            34-50    silver  female       1       0      0    1  2023-12-21
# 27            25-34    silver    male       1       1      1    0  2023-04-19
# 34            25-34      gold  female       1       1      0    0  2023-11-29
# 36            25-34    silver   other       1       1      0    0  2023-01-22
# ...             ...       ...     ...     ...     ...    ...  ...         ...
# 19977         34-50    silver   other       1       0      1    0  2023-03-06
# 19979         34-50      gold  female       1       0      1    0  2023-06-17
# 19985         25-34    silver    male       1       0      1    0  2023-06-22
# 19995         25-34      gold  female       1       0      1    0  2023-11-28
# 19999         25-34  platinum  female       1       1      1    0  2023-04-06
#
# ...

# %%
orange_data_clean
# Out:
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 1             18-25    silver  female       0       0      1    0  2023-11-23
# 2             25-34      gold  female       1       1      0    0  2023-07-27
# 3             25-34      gold  female       1       0      0    0  2023-03-03
# 4             25-34    silver  female       1       0      1    0  2023-10-09
# 5             34-50      gold  female       0       0      1    0  2023-08-18
# ...             ...       ...     ...     ...     ...    ...  ...         ...
# 19996         18-25    silver  female       0       1      0    0  2023-05-26
# 19997         18-25    silver  female       0       0      1    0  2023-08-30
# 19998         18-25    silver  female       0       0      0    1  2023-12-21
# 19999         25-34  platinum  female       1       1      1    0  2023-04-06
# 20000         18-25    silver    male       1       1      0    0  2023-12-07
#
# ...

# %%
orange_data_clean['products_owned'] = orange_data_clean[cols].sum(axis=1)
orange_data_clean[orange_data_clean['products_owned'] == 4]
# Out:
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/2336456123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orange_data_clean['products_owned'] = orange_data_clean[cols].sum(axis=1)
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 17            18-25    silver    male       1       1      1    1  2023-10-17
# 116           34-50      gold    male       1       1      1    1  2023-09-18
# 119           18-25      gold    male       1       1      1    1  2023-04-15
# 322           34-50  platinum  female       1       1      1    1  2023-04-12
# 499           25-34    silver  female       1       1      1    1  2023-12-25
# ...

# %%
orange_data_clean
# Out:
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 1             18-25    silver  female       0       0      1    0  2023-11-23
# 2             25-34      gold  female       1       1      0    0  2023-07-27
# 3             25-34      gold  female       1       0      0    0  2023-03-03
# 4             25-34    silver  female       1       0      1    0  2023-10-09
# 5             34-50      gold  female       0       0      1    0  2023-08-18
# ...             ...       ...     ...     ...     ...    ...  ...         ...
# 19996         18-25    silver  female       0       1      0    0  2023-05-26
# 19997         18-25    silver  female       0       0      1    0  2023-08-30
# 19998         18-25    silver  female       0       0      0    1  2023-12-21
# 19999         25-34  platinum  female       1       1      1    0  2023-04-06
# 20000         18-25    silver    male       1       1      0    0  2023-12-07
#
# ...

# %%
df_3_agg =orange_data_clean.groupby('tier')['products_owned'].mean().reset_index()
df_3_agg
# Out:
#        tier  products_owned
# 0      gold        1.484461
# 1  platinum        1.496120
# 2    silver        1.503344

# %%
import numpy as np
list2 = [1200, 300, 150, 2500]
product_prices = np.array(list2)
product_prices
# Out:
# array([1200,  300,  150, 2500])

# %%
orange_data_clean['sales_revenue'] = orange_data_clean['oPhone'] * product_prices[0] + orange_data_clean['oWatch'] * product_prices[1] + orange_data_clean['oPods'] * product_prices[2] + orange_data_clean['oTV'] * product_prices[3]
orange_data_clean
# Out:
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/2178335406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orange_data_clean['sales_revenue'] = orange_data_clean['oPhone'] * product_prices[0] + orange_data_clean['oWatch'] * product_prices[1] + orange_data_clean['oPods'] * product_prices[2] + orange_data_clean['oTV'] * product_prices[3]
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 1             18-25    silver  female       0       0      1    0  2023-11-23
# 2             25-34      gold  female       1       1      0    0  2023-07-27
# 3             25-34      gold  female       1       0      0    0  2023-03-03
# ...

# %%
orange_data_clean['sales_revenue'].sum()
# Out:
# np.int64(24008100)

# %%
orange_data_clean['month_of_purchase'] = pd.to_datetime(orange_data_clean['date']).dt.month
orange_data_clean
# Out:
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/750595786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orange_data_clean['month_of_purchase'] = pd.to_datetime(orange_data_clean['date']).dt.month
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 1             18-25    silver  female       0       0      1    0  2023-11-23
# 2             25-34      gold  female       1       1      0    0  2023-07-27
# 3             25-34      gold  female       1       0      0    0  2023-03-03
# 4             25-34    silver  female       1       0      1    0  2023-10-09
# 5             34-50      gold  female       0       0      1    0  2023-08-18
# ...

# %%
df_4 = pd.DataFrame(orange_data_clean.groupby('month_of_purchase', as_index=False)['sales_revenue'].sum())
df_4
# Out:
#     month_of_purchase  sales_revenue
# 0                   1        2081850
# 1                   2        1921400
# 2                   3        1875200
# 3                   4        2057150
# 4                   5        2136900
# 5                   6        1988700
# 6                   7        2079700
# 7                   8        1982100
# 8                   9        1878400
# 9                  10        2089100
# 10                 11        1873750
# 11                 12        2043850

# %%
orange_data_clean.groupby('month_of_purchase')['sales_revenue'].sum().max()
# Out:
# np.int64(2136900)

# %%
orange_data_clean.groupby('oPhone')['sales_revenue'].sum()
# Out:
# oPhone
# 0     5130000
# 1    18878100
# Name: sales_revenue, dtype: int64

# %%
orange_data_clean['oPhone_revenue'] = orange_data_clean['oPhone']* product_prices[0]
orange_data_clean['oWatch_revenue'] = orange_data_clean['oWatch']* product_prices[1]
orange_data_clean['oPods_revenue'] = orange_data_clean['oPods']* product_prices[2]
orange_data_clean['oTV_revenue'] = orange_data_clean['oTV']* product_prices[3]
orange_data_clean
# Out:
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/4258671063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orange_data_clean['oPhone_revenue'] = orange_data_clean['oPhone']* product_prices[0]
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/4258671063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orange_data_clean['oWatch_revenue'] = orange_data_clean['oWatch']* product_prices[1]
# ...

# %%
individual_revenue = pd.DataFrame({
    'oPhone_revenue': [orange_data_clean['oPhone_revenue'].sum()],
    'oWatch_revenue': [orange_data_clean['oWatch_revenue'].sum()],
    'oPods_revenue': [orange_data_clean['oPods_revenue'].sum()],
    'oTV_revenue': [orange_data_clean['oTV_revenue'].sum()]
})
individual_revenue
# Out:
#    oPhone_revenue  oWatch_revenue  oPods_revenue  oTV_revenue
# 0        14938800         1645500        1341300      6082500

# %%
# Out:
# np.int64(14938800)

# %%
orange_data_clean['oWatch_revenue'].sum()
# Out:
# np.int64(1645500)

# %%
orange_data_clean['oPods_revenue'].sum()
# Out:
# np.int64(1341300)

# %%
orange_data_clean['oTV_revenue'].sum()
# Out:
# np.int64(6082500)

# %%
df_4
# Out:
#     month_of_purchase  sales_revenue
# 0                   1        2081850
# 1                   2        1921400
# 2                   3        1875200
# 3                   4        2057150
# 4                   5        2136900
# 5                   6        1988700
# 6                   7        2079700
# 7                   8        1982100
# 8                   9        1878400
# 9                  10        2089100
# 10                 11        1873750
# 11                 12        2043850

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.bar(df_4['month_of_purchase'], df_4['sales_revenue'], width= 0.6)
plt.xlabel('Month of Purchase')
plt.xticks(range(1,13))
plt.ylabel('Sales Revenue')
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.show()

# %%
plt.pie(individual_revenue.loc[0], labels= individual_revenue.columns, autopct='%1.1f%%')
plt.show()

# %%
orange_data_clean
# Out:
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 1             18-25    silver  female       0       0      1    0  2023-11-23
# 2             25-34      gold  female       1       1      0    0  2023-07-27
# 3             25-34      gold  female       1       0      0    0  2023-03-03
# 4             25-34    silver  female       1       0      1    0  2023-10-09
# 5             34-50      gold  female       0       0      1    0  2023-08-18
# ...             ...       ...     ...     ...     ...    ...  ...         ...
# 19996         18-25    silver  female       0       1      0    0  2023-05-26
# 19997         18-25    silver  female       0       0      1    0  2023-08-30
# 19998         18-25    silver  female       0       0      0    1  2023-12-21
# 19999         25-34  platinum  female       1       1      1    0  2023-04-06
# 20000         18-25    silver    male       1       1      0    0  2023-12-07
#
# ...

# %%
df_7 = orange_data_clean.loc[(orange_data_clean['age_bracket'] == '18-25') & (orange_data_clean['oPhone'] >= 1)]
df_7
# Out:
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 8             18-25    silver  female       1       0      0    0  2023-04-23
# 13            18-25    silver    male       1       0      1    0  2023-10-07
# 15            18-25    silver   other       1       0      0    0  2023-02-14
# 17            18-25    silver    male       1       1      1    1  2023-10-17
# 18            18-25  platinum    male       1       0      1    0  2023-07-29
# ...             ...       ...     ...     ...     ...    ...  ...         ...
# 19976         18-25    silver  female       1       0      0    0  2023-03-17
# 19986         18-25      gold    male       1       0      1    0  2023-02-27
# 19987         18-25    silver    male       1       0      0    0  2023-09-06
# 19990         18-25    silver  female       1       0      1    0  2023-03-18
# 20000         18-25    silver    male       1       1      0    0  2023-12-07
#
# ...

# %%
df_7['card'].value_counts()
# Out:
# card
# Visa_debit           2405
# Mastercard_credit    1115
# Visa_credit           954
# Mastercard_debit      579
# Other_debit           355
# Other_credit           56
# Name: count, dtype: int64

# %%
df_7['total_revenue'] = df_7['oPhone_revenue'] + df_7['oWatch_revenue'] + df_7['oPods_revenue'] + df_7['oTV_revenue']
df_7
# Out:
# /var/folders/y7/6sqs5g3n71zbqjrg0n5v_8p80000gn/T/ipykernel_41925/1529595654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_7['total_revenue'] = df_7['oPhone_revenue'] + df_7['oWatch_revenue'] + df_7['oPods_revenue'] + df_7['oTV_revenue']
#         age_bracket      tier  gender  oPhone  oWatch  oPods  oTV        date  \
# user_id
# 8             18-25    silver  female       1       0      0    0  2023-04-23
# 13            18-25    silver    male       1       0      1    0  2023-10-07
# 15            18-25    silver   other       1       0      0    0  2023-02-14
# 17            18-25    silver    male       1       1      1    1  2023-10-17
# 18            18-25  platinum    male       1       0      1    0  2023-07-29
# ...

# %%
df_7['total_revenue'].mean()
# Out:
# np.float64(1522.712298682284)

# %%
df_7['products_owned'].mean()
# Out:
# np.float64(1.692532942898975)
